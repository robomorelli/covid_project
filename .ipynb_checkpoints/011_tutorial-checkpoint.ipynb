# %%
import pandas as pd
import scipy
from scipy.optimize import leastsq
import datetime
from matplotlib import pyplot
from scipy.stats import chisquare
import os
import numpy as np
import requests
from utils import *

from fit_utilities.fitter.fit import FitterTimeSeries, FitterTimeSeriesComparison

# %%
df = download_csv('regioni')

# %%
tm = FitterTimeSeries(df, 'data'
                      , select = {'denominazione_regione':['Lazio','Lombardia','Emilia-Romagna']}
                      , multiseries_on = 'denominazione_regione'
                     )

# tm = FitterTimeSeries(df, 'data'
#                       , select = {'denominazione_provincia':['Napoli', 'Caserta']}
#                       , multiseries_on = 'denominazione_provincia'
#                      )

# %%
summary = tm.fit_time_series(['totale_casi'] , 
                               start_date = '2020-10-01',end_date =None, n_previsions=7,
                             model ='logistic_der', show_test=True, semilog=False, plot=True)
# Out:
# /home/roberto/large_storage/documenti/1_Programming_Languages/Python/DEV_Python/INFN_COVID_ER/code/module/fit_utilities/fit_functions/funcs.py:37: RuntimeWarning: overflow encountered in square
#   return ((N/b)*np.exp(-(x-xmax)/b))/((1+np.exp(-(x-xmax)/b))**2)
# /home/roberto/large_storage/documenti/1_Programming_Languages/Python/DEV_Python/INFN_COVID_ER/code/module/fit_utilities/fit_functions/funcs.py:37: RuntimeWarning: overflow encountered in exp
#   return ((N/b)*np.exp(-(x-xmax)/b))/((1+np.exp(-(x-xmax)/b))**2)
# /home/roberto/large_storage/documenti/1_Programming_Languages/Python/DEV_Python/INFN_COVID_ER/code/module/fit_utilities/fit_functions/funcs.py:37: RuntimeWarning: invalid value encountered in true_divide
#   return ((N/b)*np.exp(-(x-xmax)/b))/((1+np.exp(-(x-xmax)/b))**2)
# /home/roberto/large_storage/documenti/1_Programming_Languages/Python/DEV_Python/INFN_COVID_ER/code/module/fit_utilities/fit_functions/funcs.py:37: RuntimeWarning: overflow encountered in multiply
#   return ((N/b)*np.exp(-(x-xmax)/b))/((1+np.exp(-(x-xmax)/b))**2)
# /home/roberto/large_storage/documenti/1_Programming_Languages/Python/DEV_Python/INFN_COVID_ER/code/module/fit_utilities/fitter/fit.py:115: RuntimeWarning: invalid value encountered in sqrt
#   sigma_pars = np.sqrt(np.diag(pars_fit[1]))
# /home/roberto/large_storage/documenti/1_Programming_Languages/Python/DEV_Python/INFN_COVID_ER/code/module/fit_utilities/fit_functions/funcs.py:43: RuntimeWarning: overflow encountered in square
#   return ((N/b)*np.exp(-(x-xmax)/b))/((1+np.exp(-(x-xmax)/b))**2)
# /home/roberto/anaconda3/envs/covid/lib/python3.7/site-packages/scipy/stats/stats.py:5982: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs.astype(np.float64) - f_exp)**2 / f_exp
# /home/roberto/anaconda3/envs/covid/lib/python3.7/site-packages/scipy/stats/stats.py:5982: RuntimeWarning: overflow encountered in true_divide
#   terms = (f_obs.astype(np.float64) - f_exp)**2 / f_exp

# %%
tmc=FitterTimeSeriesComparison(df, 'data'
                    , select = {'denominazione_regione':['Emilia-Romagna']}
                       ,multiseries_on = 'denominazione_regione'
                              )

# %%
summary = tmc.fit_time_series_comparison(['terapia_intensiva','totale_ospedalizzati'] ,
                               start_date = '2020-10-01',end_date ='2020-11-27', n_previsions=0,
                             model = ['gompertz', 'logistic_der'], show_test=True, semilog=False)
# Out:
# gompertz
# logistic_der
# /home/roberto/large_storage/documenti/1_Programming_Languages/Python/DEV_Python/INFN_COVID_ER/code/module/fit_utilities/fit_functions/funcs.py:4: RuntimeWarning: overflow encountered in exp
#   return c*np.exp(-a*np.exp(-b*x))
# /home/roberto/large_storage/documenti/1_Programming_Languages/Python/DEV_Python/INFN_COVID_ER/code/module/fit_utilities/fit_functions/funcs.py:4: RuntimeWarning: overflow encountered in multiply
#   return c*np.exp(-a*np.exp(-b*x))
# gompertz
# logistic_der
